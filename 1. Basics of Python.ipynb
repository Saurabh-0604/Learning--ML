# %%
#Basic Syntax in Python

print("Hello World")
# Out:
# Hello World

# %%
# Indentation

def greet(name):
    printnt(f"Hello", {name})

# %%
# Variable

first_name = "Marry"
last_name = "Jane"
age = 21

# %%
print(first_name)
print(last_name)
print(age)
# Out:
# Marry
# Jane
# 21
