# %%
# UDF user defined function designn to perform custom specific task

# Greet

def greet():
    print ("hey , welcome to the section")

# %%
# Caling a function

greet()
# Out:
# hey , welcome to the section

# %%
# function with parameter

# Myltiplying  2 nums

def multiply(x, y):
    return x * y

# %%
multiply(2,3)
# Out:
# 6

# %%
multiply(8,3)
# Out:
# 24

# %%
multiply(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 multiply(3)
#
# TypeError: multiply() missing 1 required positional argument: 'y'

# %%
# funv
