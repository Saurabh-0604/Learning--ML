# %%
# Basic data types  

first_name = "Marry"
first_name = "Jane"
ageInYears = 21
weightInKg = 60.77
isMarried = False

# %%
print(ageInYears)
# Out:
# 21

# %%
print(weightInKg)
# Out:
# 60.77

# %%
type(weightInkg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 type(weightInkg)
#
# NameError: name 'weightInkg' is not defined

# %%
type(weightInKg)
# Out:
# float

# %%
type(first_name)
# Out:
# str

# %%
type(isMarried)
# Out:
# bool

# %%
print(type(isMarried))
# Out:
# <class 'bool'>
