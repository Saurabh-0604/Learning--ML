# %%
# Creating List

empty_list = []

# fruits List

fruits = ["apple","mango","banana"]

friends = ["mary","jon","bob"]

numbers = [1,2,3,4,5]

mix = ["apple",24,33.5,False]

# %%
mix
# Out:
# ['apple', 24, 33.5, False]

# %%
friends
# Out:
# ['mary', 'jon', 'bob']

# %%
# Access The Items

friends [0]
# Out:
# 'mary'

# %%
friends[2]
# Out:
# 'bob'

# %%
# Slicing the List

mix[0:3]  #it is exclusive so, its not going to print the 3 index item
# Out:
# ['apple', 24, 33.5]

# %%
friends[0:]
# Out:
# ['mary', 'jon', 'bob']

# %%
# Methods

friends.append("Josh")

friends
# Out:
# ['mary', 'jon', 'bob', 'Josh']

# %%
friends.insert(1, "aman")

friends
# Out:
# ['mary', 'aman', 'jon', 'bob', 'Josh']

# %%
friends.remove("bob")

friends
# Out:
# ['mary', 'aman', 'jon', 'Josh']

# %%
friends.pop()

friends
# Out:
# ['mary', 'aman']

# %%
friends.pop()

friends
# Out:
# ['mary']
