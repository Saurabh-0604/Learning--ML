# %%
# Tuples are immutable
# Contains elements of different types
# Ordered --> having defined sequence


# Creating a Tuple

empty_tuple = ()

# Fruits

fruits = ("apple","banana","mango")

numbers = (1,2,3,4,5)

mix = ("apple",23,34.5, True)

name = "Jon",

# %%
type(name)
# Out:
# tuple

# %%
type(fruits)
# Out:
# tuple

# %%
type(numbers)
# Out:
# tuple

# %%
fruits[1]
# Out:
# 'banana'

# %%
# fruits[1] = "papaya"

# %%
print("hello".capitalize())
# Out:
# Hello
