# %%
# Unordered Collection of Unique Elements
# Operation - membership testing, remove duplicates, and set operations(math)

# Create a set

empty_set = {}

# Fruit

fruits = {"apple","banana","mango"}

number = {1,2,3,4}

# %%
type(fruits)
# Out:
# set

# %%
fruits = {"apple","banana","mango","apple"}

fruits
# Out:
# {'apple', 'banana', 'mango'}

# %%
# Access the Items from the Set
