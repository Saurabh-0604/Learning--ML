# %%
# Dictonaries are built-in ds store key-value pair
# ordered collection where each key is unique and used to map to a value

# Create a dictionary

empty_dict = {}

# Creating a dictionary for employee

employee = {'name': 'Alice',
            'age': 20,
            'height': 5.9}

# %%
employee
# Out:
# {'name': 'Alice', 'age': 20, 'height': 5.9}

# %%
# Access the items

employee['name']
# Out:
# 'Alice'

# %%
employee['age']
# Out:
# 20

# %%
# Modify dictionary

employee['age']=22

employee
# Out:
# {'name': 'Alice', 'age': 22, 'height': 5.9}

# %%
# Common operations on Dictionaries

employee.keys()
# Out:
# dict_keys(['name', 'age', 'height'])

# %%
employee.values()
# Out:
# dict_values(['Alice', 22, 5.9])

# %%
employee.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 22), ('height', 5.9)])

# %%
5//2
# Out:
# 2

# %%
def func(x,y=5):
    return x*y

print(func(2))
# Out:
# 10

# %%
len([1,2,3,4])
# Out:
# 4

# %%
list(map(lambda x: x**2,[1,2,3]))
# Out:
# [1, 4, 9]
